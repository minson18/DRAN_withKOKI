# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

import matplotlib.pyplot as plt 
from matplotlib.ticker import MaxNLocator

import sys
sys.path.append(r"C:\Users\levil\Personal\Project\Project5_DRAN_withKOKI")

import DRAN_function
import DRAN_withKOKI_function

# %%
params = {
    "annual_coupon_rate": 3.65,
    "par_value": 1000,
    "total_days": 7,
    "index_starting_price": 100,
    "sigma": 0.1,
    "upper_bound": 120,
    "lower_bound": 80,
    "movements_per_day": 1,  
    "binomial_with_growth": True,  
}

# Run Monte Carlo simulation
DRAN_function.run_mc_DRAN(10, show_plot=True, summary=False, **params)

# %%
params['movements_per_day'] = 100
DRAN_function.run_mc_DRAN(10, show_plot=True, **params)

# %%
params['movements_per_day'] = 1000
DRAN_function.run_mc_DRAN(10, show_plot=True, **params)

# %%
params['movements_per_day'] = 100
DRAN_function.run_mc_DRAN(1000, show_plot=False, summary=True, **params)

# %%
params['movements_per_day'] = 100
DRAN_function.run_mc_DRAN(10000, show_plot=False, summary=True, **params)

# %% [markdown]
# ## DRAN with KOKI

# %%
params = {
    "annual_coupon_rate": 3.65,
    "par_value": 1000,
    "total_days": 100,
    "index_starting_price": 0,
    "increase_rate": 0.1,
    "decrease_rate": -0.1,
    "upper_bound": 0.5,
    "lower_bound": -0.5,
    "movements_per_day": 1,  
    'ko_boundary': 0.7,
    "ki_boundary": -0.7,
    "ki_coupon_rate": 3.65 / 2,
    "movements_per_day": 100,
    "binomial_with_growth": False,
}

# %%
DRAN_withKOKI_function.run_mc_DRAN_withKOKI(1000, show_plot=False, summary=True,**params)
# Out:
# DRAN Returns Statistics:
#   Mean: 0.4297
#   Standard Deviation: 0.2707
#   Median: 0.3800
#
# DRAN Returns Distribution:
# 0.030     3
# 0.040     7
# 0.045     1
# 0.050     7
# 0.060    13
#          ..
# 0.960    11
# 0.970     9
# 0.980    15
# 0.990     8
# 1.000     8
# Name: count, Length: 204, dtype: int64
# DRAN In Bound Day Counts (in days) Statistics:
#   Mean: 46.3960
#   Standard Deviation: 28.1108
#   Median: 43.0000
#
# DRAN In Bound Day Counts (in days) Distribution:
# 3       3
# 4       7
# 5       8
# 6      12
# 7      16
#        ..
# 96     11
# 97     10
# 98     15
# 99      8
# 100     8
# Name: count, Length: 98, dtype: int64

# %% [markdown]
# ## Decrease coupon rate

# %%
params = {
    ## Half the coupon rate
    "annual_coupon_rate": 3.65 / 2,
    "par_value": 1000,
    "total_days": 100,
    "index_starting_price": 0,
    "increase_rate": 0.1,
    "decrease_rate": -0.1,
    "upper_bound": 0.5,
    "lower_bound": -0.5,
    "movements_per_day": 1,  
    'ko_boundary': 0.7,
    "ki_boundary": -0.7,
    "ki_coupon_rate": 3.65 / 2,
    "movements_per_day": 100,
    "binomial_with_growth": False,
}

DRAN_withKOKI_function.run_mc_DRAN_withKOKI(1000, show_plot=False, summary=True,**params)
# Out:
# DRAN Returns Statistics:
#   Mean: 0.2215
#   Standard Deviation: 0.1347
#   Median: 0.2000
#
# DRAN Returns Distribution:
# 0.010     4
# 0.015     6
# 0.020     4
# 0.025     9
# 0.030    11
#          ..
# 0.480     1
# 0.485     5
# 0.490     4
# 0.495     6
# 0.500    11
# Name: count, Length: 132, dtype: int64
# DRAN In Bound Day Counts (in days) Statistics:
#   Mean: 44.2910
#   Standard Deviation: 26.9443
#   Median: 40.0000
#
# DRAN In Bound Day Counts (in days) Distribution:
# 2       4
# 3       6
# 4       4
# 5       9
# 6      11
#        ..
# 96      5
# 97      5
# 98      4
# 99      6
# 100    11
# Name: count, Length: 99, dtype: int64

# %% [markdown]
# ## Increase sigma

# %%
params = {
    "annual_coupon_rate": 3.65,
    "par_value": 1000,
    "total_days": 100,
    "index_starting_price": 0,
    ## increase sigma
    "increase_rate": 0.1 * 1.5,
    "decrease_rate": -0.1 * 1.5,
    "upper_bound": 0.5,
    "lower_bound": -0.5,
    "movements_per_day": 1,  
    'ko_boundary': 0.7,
    "ki_boundary": -0.7,
    "ki_coupon_rate": 3.65 / 2,
    "movements_per_day": 100,
    "binomial_with_growth": False,
}
DRAN_withKOKI_function.run_mc_DRAN_withKOKI(1000, show_plot=False, summary=True,**params)
# Out:
# DRAN Returns Statistics:
#   Mean: 0.2144
#   Standard Deviation: 0.1605
#   Median: 0.1700
#
# DRAN Returns Distribution:
# 0.000     2
# 0.010    11
# 0.020    22
# 0.030    21
# 0.035     1
#          ..
# 0.820     1
# 0.840     1
# 0.860     1
# 0.900     2
# 0.950     1
# Name: count, Length: 173, dtype: int64
# DRAN In Bound Day Counts (in days) Statistics:
#   Mean: 25.2920
#   Standard Deviation: 19.7393
#   Median: 19.0000
#
# DRAN In Bound Day Counts (in days) Distribution:
# 0      2
# 1     11
# 2     22
# 3     20
# 4     33
#       ..
# 85     2
# 86     2
# 90     2
# 94     1
# 95     1
# Name: count, Length: 90, dtype: int64

# %% [markdown]
# ## Decrease upper bound and increase lower bound

# %%
params = {
    "annual_coupon_rate": 3.65,
    "par_value": 1000,
    "total_days": 100,
    "index_starting_price": 0,
    "increase_rate": 0.1,
    "decrease_rate": -0.1,
    # decrease upper bound and increase lower bound
    "upper_bound": 0.5 * 0.8,
    "lower_bound": -0.5 * 0.8,
    "movements_per_day": 1,  
    'ko_boundary': 0.7,
    "ki_boundary": -0.7,
    "ki_coupon_rate": 3.65 / 2,
    "movements_per_day": 100,
    "binomial_with_growth": False,
}
DRAN_withKOKI_function.run_mc_DRAN_withKOKI(1000, show_plot=False, summary=True,**params)
# Out:
# DRAN Returns Statistics:
#   Mean: 0.3499
#   Standard Deviation: 0.2464
#   Median: 0.2975
#
# DRAN Returns Distribution:
# 0.010     1
# 0.020     7
# 0.030    14
# 0.035     2
# 0.040    16
#          ..
# 0.940     2
# 0.945     1
# 0.950     2
# 0.980     1
# 0.990     4
# Name: count, Length: 181, dtype: int64
# DRAN In Bound Day Counts (in days) Statistics:
#   Mean: 37.1270
#   Standard Deviation: 25.3431
#   Median: 32.0000
#
# DRAN In Bound Day Counts (in days) Distribution:
# 1      1
# 2      7
# 3     14
# 4     18
# 5     19
#       ..
# 93     6
# 94     2
# 95     3
# 98     1
# 99     4
# Name: count, Length: 97, dtype: int64

# %% [markdown]
# ## Decrease ko boundary

# %%
params = {
    "annual_coupon_rate": 3.65,
    "par_value": 1000,
    "total_days": 100,
    "index_starting_price": 0,
    "increase_rate": 0.1,
    "decrease_rate": -0.1,
    "upper_bound": 0.5,
    "lower_bound": -0.5,
    "movements_per_day": 1, 
    # decrease ko boundary 
    'ko_boundary': 0.7 * 0.9,
    "ki_boundary": -0.7,
    "ki_coupon_rate": 3.65 / 2,
    "movements_per_day": 100,
    "binomial_with_growth": False,
}
DRAN_withKOKI_function.run_mc_DRAN_withKOKI(1000, show_plot=False, summary=True,**params)
# Out:
# DRAN Returns Statistics:
#   Mean: 0.3906
#   Standard Deviation: 0.2543
#   Median: 0.3400
#
# DRAN Returns Distribution:
# 0.010     2
# 0.020     2
# 0.025     1
# 0.030     6
# 0.040     7
#          ..
# 0.960     4
# 0.970    10
# 0.980     4
# 0.990     4
# 1.000    11
# Name: count, Length: 192, dtype: int64
# DRAN In Bound Day Counts (in days) Statistics:
#   Mean: 42.3650
#   Standard Deviation: 26.8544
#   Median: 38.0000
#
# DRAN In Bound Day Counts (in days) Distribution:
# 1       2
# 2       2
# 3       7
# 4       7
# 5      12
#        ..
# 96      4
# 97     11
# 98      4
# 99      4
# 100    11
# Name: count, Length: 100, dtype: int64

# %% [markdown]
# ## Increase ki boundary

# %%
params = {
    "annual_coupon_rate": 3.65,
    "par_value": 1000,
    "total_days": 100,
    "index_starting_price": 0,
    "increase_rate": 0.1,
    "decrease_rate": -0.1,
    "upper_bound": 0.5,
    "lower_bound": -0.5,
    "movements_per_day": 1, 
    'ko_boundary': 0.7,
    # increase ki boundary
    "ki_boundary": -0.7 * 0.9,
    "ki_coupon_rate": 3.65 / 2,
    "movements_per_day": 100,
    "binomial_with_growth": False,
}
DRAN_withKOKI_function.run_mc_DRAN_withKOKI(1000, show_plot=False, summary=True,**params)
# Out:
# DRAN Returns Statistics:
#   Mean: 0.4089
#   Standard Deviation: 0.2544
#   Median: 0.3500
#
# DRAN Returns Distribution:
# 0.02     3
# 0.03     6
# 0.04     9
# 0.05     4
# 0.06     9
#         ..
# 0.96     5
# 0.97     6
# 0.98     6
# 0.99     2
# 1.00    14
# Name: count, Length: 215, dtype: int64
# DRAN In Bound Day Counts (in days) Statistics:
#   Mean: 44.9130
#   Standard Deviation: 26.9491
#   Median: 40.0000
#
# DRAN In Bound Day Counts (in days) Distribution:
# 2       3
# 3       6
# 4       9
# 5       4
# 6       9
#        ..
# 96      5
# 97      6
# 98      6
# 99      2
# 100    14
# Name: count, Length: 99, dtype: int64

# %% [markdown]
# ## Decrease ki coupon rate

# %%
params = {
    "annual_coupon_rate": 3.65,
    "par_value": 1000,
    "total_days": 100,
    "index_starting_price": 0,
    "increase_rate": 0.1,
    "decrease_rate": -0.1,
    "upper_bound": 0.5,
    "lower_bound": -0.5,
    "movements_per_day": 1, 
    'ko_boundary': 0.7,
    "ki_boundary": -0.7 * 0.9,
    # decrease ki coupon rate
    "ki_coupon_rate": 3.65 / 2 / 2,
    "movements_per_day": 100,
    "binomial_with_growth": False,
}
DRAN_withKOKI_function.run_mc_DRAN_withKOKI(1000, show_plot=False, summary=True,**params)
# Out:
# DRAN Returns Statistics:
#   Mean: 0.3967
#   Standard Deviation: 0.2613
#   Median: 0.3300
#
# DRAN Returns Distribution:
# 0.0200     1
# 0.0300     3
# 0.0400     8
# 0.0500     8
# 0.0525     1
#           ..
# 0.9600     8
# 0.9700     5
# 0.9800    10
# 0.9900     4
# 1.0000     6
# Name: count, Length: 277, dtype: int64
# DRAN In Bound Day Counts (in days) Statistics:
#   Mean: 46.3250
#   Standard Deviation: 27.7871
#   Median: 43.0000
#
# DRAN In Bound Day Counts (in days) Distribution:
# 2       1
# 3       3
# 4       8
# 5       8
# 6      17
#        ..
# 96      9
# 97      5
# 98     10
# 99      4
# 100     6
# Name: count, Length: 99, dtype: int64
